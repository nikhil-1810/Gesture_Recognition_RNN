# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
conda uninstall scipy
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\nikhi\anaconda3
#
#   removed specs:
#     - scipy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anaconda-client-1.11.0     |   py39haa95532_0         165 KB
#     anyio-3.5.0                |   py39haa95532_0         167 KB
#     argon2-cffi-21.3.0         |     pyhd3eb1b0_0          15 KB
#     argon2-cffi-bindings-21.2.0|   py39h2bbff1b_0          36 KB
#     asttokens-2.0.5            |     pyhd3eb1b0_0          20 KB
#     attrs-21.4.0               |     pyhd3eb1b0_0          51 KB
#     backports-1.1              |     pyhd3eb1b0_0           4 KB
#     beautifulsoup4-4.11.1      |   py39haa95532_0         190 KB
#     bleach-4.1.0               |     pyhd3eb1b0_0         123 KB
#     ca-certificates-2022.10.11 |       haa95532_0         125 KB
#     certifi-2022.9.24          |   py39haa95532_0         154 KB
#     cffi-1.15.1                |   py39h2bbff1b_0         218 KB
#     click-8.0.4                |   py39haa95532_0         155 KB
#     colorama-0.4.5             |   py39haa95532_0          28 KB
#     conda-22.9.0               |   py39haa95532_0         888 KB
#     conda-build-3.22.0         |   py39haa95532_0         541 KB
#     conda-content-trust-0.1.3  |   py39haa95532_0          86 KB
#     conda-package-handling-1.9.0|   py39h8cc25b3_1         744 KB
#     conda-repo-cli-1.0.24      |   py39haa95532_0         133 KB
#     conda-token-0.4.0          |     pyhd3eb1b0_0          13 KB
#     cryptography-38.0.1        |   py39h21b164f_0         991 KB
#     debugpy-1.5.1              |   py39hd77b12b_0         2.6 MB
#     decorator-5.1.1            |     pyhd3eb1b0_0          12 KB
#     entrypoints-0.4            |   py39haa95532_0          17 KB
#     executing-0.8.3            |     pyhd3eb1b0_0          18 KB
#     fftw-3.3.9                 |       h2bbff1b_1         672 KB
#     filelock-3.6.0             |     pyhd3eb1b0_0          12 KB
#     freetype-2.12.1            |       ha860e81_0         490 KB
#     glib-2.69.1                |       h5dc1a3c_1         1.6 MB
#     gst-plugins-base-1.18.5    |       h9e645db_0         1.7 MB
#     gstreamer-1.18.5           |       hd78058f_0         1.7 MB
#     icc_rt-2022.1.0            |       h6049295_2         6.5 MB
#     idna-3.4                   |   py39haa95532_0          93 KB
#     ipykernel-6.15.2           |   py39haa95532_0         191 KB
#     ipython-8.6.0              |   py39haa95532_0         1.0 MB
#     jedi-0.18.1                |   py39haa95532_1         982 KB
#     joblib-1.1.1               |   py39haa95532_0         383 KB
#     jpeg-9e                    |       h2bbff1b_0         292 KB
#     jsonschema-4.16.0          |   py39haa95532_0         143 KB
#     jupyter_client-7.3.5       |   py39haa95532_0         211 KB
#     jupyter_core-4.11.2        |   py39haa95532_0          98 KB
#     jupyter_server-1.18.1      |   py39haa95532_0         372 KB
#     jupyterlab-3.4.4           |   py39haa95532_0         3.8 MB
#     jupyterlab_server-2.10.3   |     pyhd3eb1b0_1          48 KB
#     libarchive-3.6.1           |       hebabd0d_0         1.7 MB
#     libclang-12.0.0            |default_h627e005_2        17.8 MB
#     libffi-3.4.2               |       hd77b12b_4         107 KB
#     libiconv-1.16              |       h2bbff1b_2         651 KB
#     liblief-0.11.5             |       hd77b12b_1         2.1 MB
#     libogg-1.3.5               |       h2bbff1b_1          33 KB
#     libsodium-1.0.18           |       h62dcd97_0         477 KB
#     libtiff-4.4.0              |       h8a3f274_1         832 KB
#     libvorbis-1.3.7            |       he774522_0         202 KB
#     libwebp-1.2.4              |       h2bbff1b_0          67 KB
#     libwebp-base-1.2.4         |       h2bbff1b_0         279 KB
#     libxml2-2.9.14             |       h0ad7f3c_0         1.5 MB
#     libxslt-1.1.35             |       h2bbff1b_0         407 KB
#     m2-msys2-runtime-2.5.0.17080.65c939c|                3         3.0 MB
#     m2-patch-2.7.5             |                2          89 KB
#     markupsafe-2.0.1           |   py39h2bbff1b_0          24 KB
#     matplotlib-inline-0.1.6    |   py39haa95532_0          17 KB
#     nbclassic-0.4.8            |   py39haa95532_0         5.9 MB
#     nbclient-0.5.13            |   py39haa95532_0         108 KB
#     nbconvert-6.4.4            |   py39haa95532_0         517 KB
#     nbformat-5.5.0             |   py39haa95532_0         146 KB
#     nest-asyncio-1.5.5         |   py39haa95532_0          16 KB
#     notebook-6.5.2             |   py39haa95532_0         538 KB
#     notebook-shim-0.2.2        |   py39haa95532_0          23 KB
#     numpy-1.23.3               |   py39h3b20f71_0          11 KB
#     numpy-base-1.23.3          |   py39h4da318b_0         5.0 MB
#     openssl-1.1.1s             |       h2bbff1b_0         5.5 MB
#     packaging-21.3             |     pyhd3eb1b0_0          36 KB
#     pandocfilters-1.5.0        |     pyhd3eb1b0_0          11 KB
#     parso-0.8.3                |     pyhd3eb1b0_0          70 KB
#     pathlib-1.0.1              |     pyhd3eb1b0_1          17 KB
#     pcre-8.45                  |       hd77b12b_0         382 KB
#     pillow-9.2.0               |   py39hdc2b20a_1         908 KB
#     pip-22.2.2                 |   py39haa95532_0         2.3 MB
#     pkginfo-1.8.3              |   py39haa95532_0          62 KB
#     prometheus_client-0.14.1   |   py39haa95532_0          89 KB
#     psutil-5.9.0               |   py39h2bbff1b_0         349 KB
#     pure_eval-0.2.2            |     pyhd3eb1b0_0          14 KB
#     py-lief-0.11.5             |   py39hd77b12b_1         1.7 MB
#     pycosat-0.6.4              |   py39h2bbff1b_0          74 KB
#     pycparser-2.21             |     pyhd3eb1b0_0          94 KB
#     pygments-2.11.2            |     pyhd3eb1b0_0         759 KB
#     pyjwt-2.4.0                |   py39haa95532_0          38 KB
#     pyopenssl-22.0.0           |     pyhd3eb1b0_0          50 KB
#     pyparsing-3.0.9            |   py39haa95532_0         152 KB
#     pyqt-5.15.7                |   py39hd77b12b_0         3.7 MB
#     pyqt5-sip-12.11.0          |   py39hd77b12b_0          75 KB
#     python-fastjsonschema-2.16.2|   py39haa95532_0         231 KB
#     pytz-2022.1                |   py39haa95532_0         195 KB
#     pywin32-302                |   py39h2bbff1b_2         5.6 MB
#     pywinpty-2.0.2             |   py39h5da7b33_0         200 KB
#     pyzmq-23.2.0               |   py39hd77b12b_0         404 KB
#     qt-main-5.15.2             |       he8e5bd7_7        50.0 MB
#     qt-webengine-5.15.9        |       hb9a9bb5_4        48.9 MB
#     qtpy-2.2.0                 |   py39haa95532_0         106 KB
#     qtwebkit-5.212             |       h3ad3cdb_4        10.3 MB
#     requests-2.28.1            |   py39haa95532_0          99 KB
#     scikit-learn-1.1.3         |   py39hd77b12b_0         6.3 MB
#     scipy-1.9.3                |   py39he11b74f_0        18.0 MB
#     setuptools-65.5.0          |   py39haa95532_0         1.1 MB
#     sip-6.6.2                  |   py39hd77b12b_0         434 KB
#     six-1.16.0                 |     pyhd3eb1b0_1          18 KB
#     soupsieve-2.3.2.post1      |   py39haa95532_0          66 KB
#     sqlite-3.39.3              |       h2bbff1b_0         804 KB
#     stack_data-0.2.0           |     pyhd3eb1b0_0          22 KB
#     tbb-2021.6.0               |       h59b6b97_0         135 KB
#     tenacity-8.0.1             |   py39haa95532_1          34 KB
#     terminado-0.13.1           |   py39haa95532_0          31 KB
#     testpath-0.6.0             |   py39haa95532_0          85 KB
#     tk-8.6.12                  |       h2bbff1b_0         3.1 MB
#     toolz-0.12.0               |   py39haa95532_0         106 KB
#     tornado-6.2                |   py39h2bbff1b_0         609 KB
#     tqdm-4.64.1                |   py39haa95532_0         143 KB
#     traitlets-5.1.1            |     pyhd3eb1b0_0          84 KB
#     typing-extensions-4.3.0    |   py39haa95532_0           9 KB
#     typing_extensions-4.3.0    |   py39haa95532_0          42 KB
#     tzdata-2022f               |       h04d1e81_0         115 KB
#     ujson-5.4.0                |   py39hd77b12b_0          44 KB
#     urllib3-1.26.12            |   py39haa95532_0         185 KB
#     websocket-client-0.58.0    |   py39haa95532_4          69 KB
#     wheel-0.37.1               |     pyhd3eb1b0_0          33 KB
#     widgetsnbextension-3.5.2   |   py39haa95532_0         646 KB
#     xz-5.2.6                   |       h8cc25b3_0         240 KB
#     zeromq-4.3.4               |       hd77b12b_0         4.2 MB
#     zlib-1.2.13                |       h8cc25b3_0         113 KB
#     zstd-1.5.2                 |       h19a0ad4_0         509 KB
#     ------------------------------------------------------------
#                                            Total:       238.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   argon2-cffi-bindi~ pkgs/main/win-64::argon2-cffi-bindings-21.2.0-py39h2bbff1b_0
#   asttokens          pkgs/main/noarch::asttokens-2.0.5-pyhd3eb1b0_0
#   executing          pkgs/main/noarch::executing-0.8.3-pyhd3eb1b0_0
#   fftw               pkgs/main/win-64::fftw-3.3.9-h2bbff1b_1
#   glib               pkgs/main/win-64::glib-2.69.1-h5dc1a3c_1
#   gst-plugins-base   pkgs/main/win-64::gst-plugins-base-1.18.5-h9e645db_0
#   gstreamer          pkgs/main/win-64::gstreamer-1.18.5-hd78058f_0
#   libclang           pkgs/main/win-64::libclang-12.0.0-default_h627e005_2
#   libffi             pkgs/main/win-64::libffi-3.4.2-hd77b12b_4
#   libogg             pkgs/main/win-64::libogg-1.3.5-h2bbff1b_1
#   libsodium          pkgs/main/win-64::libsodium-1.0.18-h62dcd97_0
#   libvorbis          pkgs/main/win-64::libvorbis-1.3.7-he774522_0
#   libwebp-base       pkgs/main/win-64::libwebp-base-1.2.4-h2bbff1b_0
#   m2-msys2-runtime   pkgs/msys2/win-64::m2-msys2-runtime-2.5.0.17080.65c939c-3
#   m2-patch           pkgs/msys2/win-64::m2-patch-2.7.5-2
#   notebook-shim      pkgs/main/win-64::notebook-shim-0.2.2-py39haa95532_0
#   pathlib            pkgs/main/noarch::pathlib-1.0.1-pyhd3eb1b0_1
#   pcre               pkgs/main/win-64::pcre-8.45-hd77b12b_0
#   pure_eval          pkgs/main/noarch::pure_eval-0.2.2-pyhd3eb1b0_0
#   pyqt5-sip          pkgs/main/win-64::pyqt5-sip-12.11.0-py39hd77b12b_0
#   python-fastjsonsc~ pkgs/main/win-64::python-fastjsonschema-2.16.2-py39haa95532_0
#   qt-main            pkgs/main/win-64::qt-main-5.15.2-he8e5bd7_7
#   qt-webengine       pkgs/main/win-64::qt-webengine-5.15.9-hb9a9bb5_4
#   qtwebkit           pkgs/main/win-64::qtwebkit-5.212-h3ad3cdb_4
#   scikit-learn       pkgs/main/win-64::scikit-learn-1.1.3-py39hd77b12b_0
#   stack_data         pkgs/main/noarch::stack_data-0.2.0-pyhd3eb1b0_0
#   typing-extensions  pkgs/main/win-64::typing-extensions-4.3.0-py39haa95532_0
#   websocket-client   pkgs/main/win-64::websocket-client-0.58.0-py39haa95532_4
#   zeromq             pkgs/main/win-64::zeromq-4.3.4-hd77b12b_0
#
# The following packages will be REMOVED:
#
#   anaconda-2021.11-py39_0
#   astropy-4.3.1-py39hc7d831d_0
#   patsy-0.5.2-py39haa95532_0
#   scikit-image-0.18.3-py39hf11a4ad_0
#   seaborn-0.11.2-pyhd3eb1b0_0
#   statsmodels-0.12.2-py39h2bbff1b_0
#
# The following packages will be UPDATED:
#
#   anaconda-client                      1.9.0-py39haa95532_0 --> 1.11.0-py39haa95532_0
#   anyio                                2.2.0-py39haa95532_2 --> 3.5.0-py39haa95532_0
#   argon2-cffi        pkgs/main/win-64::argon2-cffi-20.1.0-~ --> pkgs/main/noarch::argon2-cffi-21.3.0-pyhd3eb1b0_0
#   attrs                                 21.2.0-pyhd3eb1b0_0 --> 21.4.0-pyhd3eb1b0_0
#   backports                                1.0-pyhd3eb1b0_2 --> 1.1-pyhd3eb1b0_0
#   beautifulsoup4     pkgs/main/noarch::beautifulsoup4-4.10~ --> pkgs/main/win-64::beautifulsoup4-4.11.1-py39haa95532_0
#   bleach                                 4.0.0-pyhd3eb1b0_0 --> 4.1.0-pyhd3eb1b0_0
#   ca-certificates                     2021.10.26-haa95532_2 --> 2022.10.11-haa95532_0
#   certifi                          2021.10.8-py39haa95532_0 --> 2022.9.24-py39haa95532_0
#   cffi                                1.14.6-py39h2bbff1b_0 --> 1.15.1-py39h2bbff1b_0
#   click              pkgs/main/noarch::click-8.0.3-pyhd3eb~ --> pkgs/main/win-64::click-8.0.4-py39haa95532_0
#   colorama           pkgs/main/noarch::colorama-0.4.4-pyhd~ --> pkgs/main/win-64::colorama-0.4.5-py39haa95532_0
#   conda                               4.12.0-py39haa95532_0 --> 22.9.0-py39haa95532_0
#   conda-build                         3.21.6-py39haa95532_0 --> 3.22.0-py39haa95532_0
#   conda-content-tru~ pkgs/main/noarch::conda-content-trust~ --> pkgs/main/win-64::conda-content-trust-0.1.3-py39haa95532_0
#   conda-package-han~                   1.7.3-py39h8cc25b3_1 --> 1.9.0-py39h8cc25b3_1
#   conda-repo-cli     pkgs/main/noarch::conda-repo-cli-1.0.~ --> pkgs/main/win-64::conda-repo-cli-1.0.24-py39haa95532_0
#   conda-token                            0.3.0-pyhd3eb1b0_0 --> 0.4.0-pyhd3eb1b0_0
#   cryptography                         3.4.8-py39h71e12ea_0 --> 38.0.1-py39h21b164f_0
#   debugpy                              1.4.1-py39hd77b12b_0 --> 1.5.1-py39hd77b12b_0
#   decorator                              5.1.0-pyhd3eb1b0_0 --> 5.1.1-pyhd3eb1b0_0
#   entrypoints                            0.3-py39haa95532_0 --> 0.4-py39haa95532_0
#   filelock                               3.3.1-pyhd3eb1b0_1 --> 3.6.0-pyhd3eb1b0_0
#   freetype                                2.10.4-hd328e21_0 --> 2.12.1-ha860e81_0
#   icc_rt                                2019.0.0-h0cc432a_1 --> 2022.1.0-h6049295_2
#   idna               pkgs/main/noarch::idna-3.2-pyhd3eb1b0~ --> pkgs/main/win-64::idna-3.4-py39haa95532_0
#   ipykernel                            6.4.1-py39haa95532_1 --> 6.15.2-py39haa95532_0
#   ipython                             7.29.0-py39hd4e2768_0 --> 8.6.0-py39haa95532_0
#   jedi                                0.18.0-py39haa95532_1 --> 0.18.1-py39haa95532_1
#   joblib             pkgs/main/noarch::joblib-1.1.0-pyhd3e~ --> pkgs/main/win-64::joblib-1.1.1-py39haa95532_0
#   jpeg                                        9d-h2bbff1b_0 --> 9e-h2bbff1b_0
#
# Note: you may need to restart the kernel to use updated packages.  jsonschema         pkgs/main/noarch::jsonschema-3.2.0-py~ --> pkgs/main/win-64::jsonschema-4.16.0-py39haa95532_0
#   jupyter_client     pkgs/main/noarch::jupyter_client-6.1.~ --> pkgs/main/win-64::jupyter_client-7.3.5-py39haa95532_0
#   jupyter_core                         4.8.1-py39haa95532_0 --> 4.11.2-py39haa95532_0
#   jupyter_server                       1.4.1-py39haa95532_0 --> 1.18.1-py39haa95532_0
#   jupyterlab         pkgs/main/noarch::jupyterlab-3.2.1-py~ --> pkgs/main/win-64::jupyterlab-3.4.4-py39haa95532_0
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::scikit-learn-intelex==2021.3.0=py39haa95532_0
#   jupyterlab_server                      2.8.2-pyhd3eb1b0_0 --> 2.10.3-pyhd3eb1b0_1
#   libarchive                               3.4.2-h5e25573_0 --> 3.6.1-hebabd0d_0
#   libiconv                                  1.15-h1df5818_7 --> 1.16-h2bbff1b_2
#   liblief                                 0.10.1-hd77b12b_1 --> 0.11.5-hd77b12b_1
#   libtiff                                  4.2.0-hd0e1b90_0 --> 4.4.0-h8a3f274_1
#   libwebp                                  1.2.0-h2bbff1b_0 --> 1.2.4-h2bbff1b_0
#   libxml2                                 2.9.12-h0ad7f3c_0 --> 2.9.14-h0ad7f3c_0
#   libxslt                                 1.1.34-he774522_0 --> 1.1.35-h2bbff1b_0
#   markupsafe                           1.1.1-py39h2bbff1b_0 --> 2.0.1-py39h2bbff1b_0
#   matplotlib-inline  pkgs/main/noarch::matplotlib-inline-0~ --> pkgs/main/win-64::matplotlib-inline-0.1.6-py39haa95532_0
#   nbclassic          pkgs/main/noarch::nbclassic-0.2.6-pyh~ --> pkgs/main/win-64::nbclassic-0.4.8-py39haa95532_0
#   nbclient           pkgs/main/noarch::nbclient-0.5.3-pyhd~ --> pkgs/main/win-64::nbclient-0.5.13-py39haa95532_0
#   nbconvert                            6.1.0-py39haa95532_0 --> 6.4.4-py39haa95532_0
#   nbformat           pkgs/main/noarch::nbformat-5.1.3-pyhd~ --> pkgs/main/win-64::nbformat-5.5.0-py39haa95532_0
#   nest-asyncio       pkgs/main/noarch::nest-asyncio-1.5.1-~ --> pkgs/main/win-64::nest-asyncio-1.5.5-py39haa95532_0
#   notebook                             6.4.5-py39haa95532_0 --> 6.5.2-py39haa95532_0
#   numpy                               1.20.3-py39ha4e8547_0 --> 1.23.3-py39h3b20f71_0
#   numpy-base                          1.20.3-py39hc2deb75_0 --> 1.23.3-py39h4da318b_0
#   openssl                                 1.1.1l-h2bbff1b_0 --> 1.1.1s-h2bbff1b_0
#   packaging                               21.0-pyhd3eb1b0_0 --> 21.3-pyhd3eb1b0_0
#   pandocfilters      pkgs/main/win-64::pandocfilters-1.4.3~ --> pkgs/main/noarch::pandocfilters-1.5.0-pyhd3eb1b0_0
#   parso                                  0.8.2-pyhd3eb1b0_0 --> 0.8.3-pyhd3eb1b0_0
#   pillow                               8.4.0-py39hd45dc43_0 --> 9.2.0-py39hdc2b20a_1
#   pip                                 21.2.4-py39haa95532_0 --> 22.2.2-py39haa95532_0
#   pkginfo                              1.7.1-py39haa95532_0 --> 1.8.3-py39haa95532_0
#   prometheus_client  pkgs/main/noarch::prometheus_client-0~ --> pkgs/main/win-64::prometheus_client-0.14.1-py39haa95532_0
#   psutil                               5.8.0-py39h2bbff1b_1 --> 5.9.0-py39h2bbff1b_0
#   py-lief                             0.10.1-py39hd77b12b_1 --> 0.11.5-py39hd77b12b_1
#   pycosat                              0.6.3-py39h2bbff1b_0 --> 0.6.4-py39h2bbff1b_0
#   pycparser                                       2.20-py_2 --> 2.21-pyhd3eb1b0_0
#   pygments                              2.10.0-pyhd3eb1b0_0 --> 2.11.2-pyhd3eb1b0_0
#   pyjwt                                2.1.0-py39haa95532_0 --> 2.4.0-py39haa95532_0
#   pyopenssl                             21.0.0-pyhd3eb1b0_1 --> 22.0.0-pyhd3eb1b0_0
#   pyparsing          pkgs/main/noarch::pyparsing-3.0.4-pyh~ --> pkgs/main/win-64::pyparsing-3.0.9-py39haa95532_0
#   pyqt                                 5.9.2-py39hd77b12b_6 --> 5.15.7-py39hd77b12b_0
#   pytz               pkgs/main/noarch::pytz-2021.3-pyhd3eb~ --> pkgs/main/win-64::pytz-2022.1-py39haa95532_0
#   pywin32                                228-py39he774522_0 --> 302-py39h2bbff1b_2
#   pywinpty                             0.5.7-py39haa95532_0 --> 2.0.2-py39h5da7b33_0
#   pyzmq                               22.2.1-py39hd77b12b_1 --> 23.2.0-py39hd77b12b_0
#   qtpy               pkgs/main/noarch::qtpy-1.10.0-pyhd3eb~ --> pkgs/main/win-64::qtpy-2.2.0-py39haa95532_0
#   requests           pkgs/main/noarch::requests-2.26.0-pyh~ --> pkgs/main/win-64::requests-2.28.1-py39haa95532_0
#   scipy                                1.7.1-py39hbe87c03_2 --> 1.9.3-py39he11b74f_0
#   setuptools                          58.0.4-py39haa95532_0 --> 65.5.0-py39haa95532_0
#   sip                                4.19.13-py39hd77b12b_0 --> 6.6.2-py39hd77b12b_0
#   six                                   1.16.0-pyhd3eb1b0_0 --> 1.16.0-pyhd3eb1b0_1
#   soupsieve          pkgs/main/noarch::soupsieve-2.2.1-pyh~ --> pkgs/main/win-64::soupsieve-2.3.2.post1-py39haa95532_0
#   sqlite                                  3.36.0-h2bbff1b_0 --> 3.39.3-h2bbff1b_0
#   tbb                                   2021.4.0-h59b6b97_0 --> 2021.6.0-h59b6b97_0
#   tenacity                             8.0.1-py39haa95532_0 --> 8.0.1-py39haa95532_1
#   terminado                            0.9.4-py39haa95532_0 --> 0.13.1-py39haa95532_0
#   testpath           pkgs/main/noarch::testpath-0.5.0-pyhd~ --> pkgs/main/win-64::testpath-0.6.0-py39haa95532_0
#   tk                                      8.6.11-h2bbff1b_0 --> 8.6.12-h2bbff1b_0
#   toolz              pkgs/main/noarch::toolz-0.11.1-pyhd3e~ --> pkgs/main/win-64::toolz-0.12.0-py39haa95532_0
#   tornado                                6.1-py39h2bbff1b_0 --> 6.2-py39h2bbff1b_0
#   tqdm               pkgs/main/noarch::tqdm-4.62.3-pyhd3eb~ --> pkgs/main/win-64::tqdm-4.64.1-py39haa95532_0
#   traitlets                              5.1.0-pyhd3eb1b0_0 --> 5.1.1-pyhd3eb1b0_0
#   typing_extensions  pkgs/main/noarch::typing_extensions-3~ --> pkgs/main/win-64::typing_extensions-4.3.0-py39haa95532_0
#   tzdata                                   2021e-hda174b7_0 --> 2022f-h04d1e81_0
#   ujson                                4.0.2-py39hd77b12b_0 --> 5.4.0-py39hd77b12b_0
#   urllib3            pkgs/main/noarch::urllib3-1.26.7-pyhd~ --> pkgs/main/win-64::urllib3-1.26.12-py39haa95532_0
#   wheel                                 0.37.0-pyhd3eb1b0_1 --> 0.37.1-pyhd3eb1b0_0
#   widgetsnbextension                   3.5.1-py39haa95532_0 --> 3.5.2-py39haa95532_0
#   xz                                       5.2.5-h62dcd97_0 --> 5.2.6-h8cc25b3_0
#   zlib                                    1.2.11-h62dcd97_4 --> 1.2.13-h8cc25b3_0
#   zstd                                     1.4.9-h19a0ad4_0 --> 1.5.2-h19a0ad4_0
#
#
#
# Downloading and Extracting Packages
#
# widgetsnbextension-3 | 646 KB    |            |   0%
# widgetsnbextension-3 | 646 KB    | 2          |   2%
# widgetsnbextension-3 | 646 KB    | 7          |   7%
# widgetsnbextension-3 | 646 KB    | #9         |  20%
# widgetsnbextension-3 | 646 KB    | ###7       |  37%
# widgetsnbextension-3 | 646 KB    | #####6     |  57%
# widgetsnbextension-3 | 646 KB    | #########4 |  94%
# widgetsnbextension-3 | 646 KB    | ########## | 100%
#
# libwebp-1.2.4        | 67 KB     |            |   0%
# libwebp-1.2.4        | 67 KB     | ##3        |  24%
# libwebp-1.2.4        | 67 KB     | ########## | 100%
#
# libiconv-1.16        | 651 KB    |            |   0%
# libiconv-1.16        | 651 KB    | 2          |   2%
# libiconv-1.16        | 651 KB    | #########5 |  96%
# libiconv-1.16        | 651 KB    | ########## | 100%
#
# notebook-6.5.2       | 538 KB    |            |   0%
# notebook-6.5.2       | 538 KB    | 2          |   3%
# notebook-6.5.2       | 538 KB    | ########## | 100%
# notebook-6.5.2       | 538 KB    | ########## | 100%
#
# prometheus_client-0. | 89 KB     |            |   0%
# prometheus_client-0. | 89 KB     | #7         |  18%
# prometheus_client-0. | 89 KB     | ########## | 100%
#
# nbformat-5.5.0       | 146 KB    |            |   0%
# nbformat-5.5.0       | 146 KB    | #          |  11%
# nbformat-5.5.0       | 146 KB    | ########## | 100%
# nbformat-5.5.0       | 146 KB    | ########## | 100%
#
# libwebp-base-1.2.4   | 279 KB    |            |   0%
# libwebp-base-1.2.4   | 279 KB    | 5          |   6%
# libwebp-base-1.2.4   | 279 KB    | ########## | 100%
#
# openssl-1.1.1s       | 5.5 MB    |            |   0%
# openssl-1.1.1s       | 5.5 MB    |            |   0%
# openssl-1.1.1s       | 5.5 MB    | ###1       |  31%
# openssl-1.1.1s       | 5.5 MB    | ######4    |  65%
# openssl-1.1.1s       | 5.5 MB    | ########## | 100%
# openssl-1.1.1s       | 5.5 MB    | ########## | 100%
#
# cffi-1.15.1          | 218 KB    |            |   0%
# cffi-1.15.1          | 218 KB    | 7          |   7%
# cffi-1.15.1          | 218 KB    | ########## | 100%
#
# zlib-1.2.13          | 113 KB    |            |   0%
# zlib-1.2.13          | 113 KB    | #4         |  14%
# zlib-1.2.13          | 113 KB    | ########## | 100%
#
# libarchive-3.6.1     | 1.7 MB    |            |   0%
# libarchive-3.6.1     | 1.7 MB    |            |   1%
# libarchive-3.6.1     | 1.7 MB    | ########## | 100%
# libarchive-3.6.1     | 1.7 MB    | ########## | 100%
#
# ca-certificates-2022 | 125 KB    |            |   0%
# ca-certificates-2022 | 125 KB    | #2         |  13%
# ca-certificates-2022 | 125 KB    | ########## | 100%
#
# pytz-2022.1          | 195 KB    |            |   0%
# pytz-2022.1          | 195 KB    | 8          |   8%
# pytz-2022.1          | 195 KB    | ########## | 100%
# pytz-2022.1          | 195 KB    | ########## | 100%
#
# typing-extensions-4. | 9 KB      |            |   0%
# typing-extensions-4. | 9 KB      | ########## | 100%
# typing-extensions-4. | 9 KB      | ########## | 100%
#
# jupyter_server-1.18. | 372 KB    |            |   0%
# jupyter_server-1.18. | 372 KB    | 4          |   4%
# jupyter_server-1.18. | 372 KB    | ########## | 100%
# jupyter_server-1.18. | 372 KB    | ########## | 100%
#
# pathlib-1.0.1        | 17 KB     |            |   0%
# pathlib-1.0.1        | 17 KB     | #########2 |  93%
# pathlib-1.0.1        | 17 KB     | ########## | 100%
#
# tenacity-8.0.1       | 34 KB     |            |   0%
# tenacity-8.0.1       | 34 KB     | ####6      |  46%
# tenacity-8.0.1       | 34 KB     | ########## | 100%
#
# jupyterlab_server-2. | 48 KB     |            |   0%
# jupyterlab_server-2. | 48 KB     | ###3       |  34%
# jupyterlab_server-2. | 48 KB     | ########## | 100%
#
# conda-22.9.0         | 888 KB    |            |   0%
# conda-22.9.0         | 888 KB    | 1          |   2%
# conda-22.9.0         | 888 KB    | ########## | 100%
# conda-22.9.0         | 888 KB    | ########## | 100%
#
# pcre-8.45            | 382 KB    |            |   0%
# pcre-8.45            | 382 KB    | 4          |   4%
# pcre-8.45            | 382 KB    | ########## | 100%
# pcre-8.45            | 382 KB    | ########## | 100%
#
# pyqt-5.15.7          | 3.7 MB    |            |   0%
# pyqt-5.15.7          | 3.7 MB    |            |   0%
# pyqt-5.15.7          | 3.7 MB    | ########5  |  86%
# pyqt-5.15.7          | 3.7 MB    | ########## | 100%
#
# stack_data-0.2.0     | 22 KB     |            |   0%
# stack_data-0.2.0     | 22 KB     | #######2   |  72%
# stack_data-0.2.0     | 22 KB     | ########## | 100%
#
# cryptography-38.0.1  | 991 KB    |            |   0%
# cryptography-38.0.1  | 991 KB    | 1          |   2%
# cryptography-38.0.1  | 991 KB    | ########## | 100%
# cryptography-38.0.1  | 991 KB    | ########## | 100%
#
# pywin32-302          | 5.6 MB    |            |   0%
# pywin32-302          | 5.6 MB    |            |   0%
# pywin32-302          | 5.6 MB    | #####2     |  53%
# pywin32-302          | 5.6 MB    | ########3  |  84%
# pywin32-302          | 5.6 MB    | ########## | 100%
#
# pure_eval-0.2.2      | 14 KB     |            |   0%
# pure_eval-0.2.2      | 14 KB     | ########## | 100%
# pure_eval-0.2.2      | 14 KB     | ########## | 100%
#
# pyzmq-23.2.0         | 404 KB    |            |   0%
# pyzmq-23.2.0         | 404 KB    | 3          |   4%
# pyzmq-23.2.0         | 404 KB    | ########## | 100%
# pyzmq-23.2.0         | 404 KB    | ########## | 100%
#
# jsonschema-4.16.0    | 143 KB    |            |   0%
# jsonschema-4.16.0    | 143 KB    | #1         |  11%
# jsonschema-4.16.0    | 143 KB    | ########## | 100%
# jsonschema-4.16.0    | 143 KB    | ########## | 100%
#
# xz-5.2.6             | 240 KB    |            |   0%
# xz-5.2.6             | 240 KB    | 6          |   7%
# xz-5.2.6             | 240 KB    | ########## | 100%
# xz-5.2.6             | 240 KB    | ########## | 100%
#
# numpy-base-1.23.3    | 5.0 MB    |            |   0%
# numpy-base-1.23.3    | 5.0 MB    |            |   0%
# numpy-base-1.23.3    | 5.0 MB    | 2          |   3%
# numpy-base-1.23.3    | 5.0 MB    | #5         |  15%
# numpy-base-1.23.3    | 5.0 MB    | ##2        |  23%
# numpy-base-1.23.3    | 5.0 MB    | ###1       |  31%
# numpy-base-1.23.3    | 5.0 MB    | ###9       |  39%
# numpy-base-1.23.3    | 5.0 MB    | ####7      |  47%
# numpy-base-1.23.3    | 5.0 MB    | #####5     |  55%
# numpy-base-1.23.3    | 5.0 MB    | ######4    |  65%
# numpy-base-1.23.3    | 5.0 MB    | #######3   |  74%
# numpy-base-1.23.3    | 5.0 MB    | ########2  |  82%
# numpy-base-1.23.3    | 5.0 MB    | #########5 |  96%
# numpy-base-1.23.3    | 5.0 MB    | ########## | 100%
#
# parso-0.8.3          | 70 KB     |            |   0%
# parso-0.8.3          | 70 KB     | ##2        |  23%
# parso-0.8.3          | 70 KB     | ########## | 100%
#
# tk-8.6.12            | 3.1 MB    |            |   0%
# tk-8.6.12            | 3.1 MB    |            |   1%
# tk-8.6.12            | 3.1 MB    | #5         |  15%
# tk-8.6.12            | 3.1 MB    | ##9        |  30%
# tk-8.6.12            | 3.1 MB    | ####6      |  47%
# tk-8.6.12            | 3.1 MB    | ######7    |  67%
# tk-8.6.12            | 3.1 MB    | ########3  |  83%
# tk-8.6.12            | 3.1 MB    | ########## | 100%
# tk-8.6.12            | 3.1 MB    | ########## | 100%
#
# ipython-8.6.0        | 1.0 MB    |            |   0%
# ipython-8.6.0        | 1.0 MB    | 1          |   2%
# ipython-8.6.0        | 1.0 MB    | #####4     |  55%
# ipython-8.6.0        | 1.0 MB    | #########1 |  91%
# ipython-8.6.0        | 1.0 MB    | ########## | 100%
#
# testpath-0.6.0       | 85 KB     |            |   0%
# testpath-0.6.0       | 85 KB     | #8         |  19%
# testpath-0.6.0       | 85 KB     | ########## | 100%
#
# nbclassic-0.4.8      | 5.9 MB    |            |   0%
# nbclassic-0.4.8      | 5.9 MB    |            |   0%
# nbclassic-0.4.8      | 5.9 MB    | 9          |  10%
# nbclassic-0.4.8      | 5.9 MB    | ##         |  21%
# nbclassic-0.4.8      | 5.9 MB    | ###        |  30%
# nbclassic-0.4.8      | 5.9 MB    | ####1      |  41%
# nbclassic-0.4.8      | 5.9 MB    | #####2     |  53%
# nbclassic-0.4.8      | 5.9 MB    | ######3    |  64%
# nbclassic-0.4.8      | 5.9 MB    | #######5   |  75%
# nbclassic-0.4.8      | 5.9 MB    | ########6  |  87%
# nbclassic-0.4.8      | 5.9 MB    | #########7 |  98%
# nbclassic-0.4.8      | 5.9 MB    | ########## | 100%
#
# icc_rt-2022.1.0      | 6.5 MB    |            |   0%
# icc_rt-2022.1.0      | 6.5 MB    |            |   0%
# icc_rt-2022.1.0      | 6.5 MB    | #1         |  11%
# icc_rt-2022.1.0      | 6.5 MB    | ##4        |  24%
# icc_rt-2022.1.0      | 6.5 MB    | ###4       |  35%
# icc_rt-2022.1.0      | 6.5 MB    | ####7      |  48%
# icc_rt-2022.1.0      | 6.5 MB    | ######     |  61%
# icc_rt-2022.1.0      | 6.5 MB    | #######3   |  73%
# icc_rt-2022.1.0      | 6.5 MB    | ########6  |  86%
# icc_rt-2022.1.0      | 6.5 MB    | #########9 |  99%
# icc_rt-2022.1.0      | 6.5 MB    | ########## | 100%
#
# conda-package-handli | 744 KB    |            |   0%
# conda-package-handli | 744 KB    | 2          |   2%
# conda-package-handli | 744 KB    | ########## | 100%
# conda-package-handli | 744 KB    | ########## | 100%
#
# jupyter_client-7.3.5 | 211 KB    |            |   0%
# jupyter_client-7.3.5 | 211 KB    | 7          |   8%
# jupyter_client-7.3.5 | 211 KB    | ########## | 100%
# jupyter_client-7.3.5 | 211 KB    | ########## | 100%
#
# argon2-cffi-bindings | 36 KB     |            |   0%
# argon2-cffi-bindings | 36 KB     | ####4      |  45%
# argon2-cffi-bindings | 36 KB     | ########## | 100%
#
# colorama-0.4.5       | 28 KB     |            |   0%
# colorama-0.4.5       | 28 KB     | #####7     |  57%
# colorama-0.4.5       | 28 KB     | ########## | 100%
#
# argon2-cffi-21.3.0   | 15 KB     |            |   0%
# argon2-cffi-21.3.0   | 15 KB     | ########## | 100%
# argon2-cffi-21.3.0   | 15 KB     | ########## | 100%
#
# fftw-3.3.9           | 672 KB    |            |   0%
# fftw-3.3.9           | 672 KB    | 2          |   2%
# fftw-3.3.9           | 672 KB    | ########## | 100%
# fftw-3.3.9           | 672 KB    | ########## | 100%
#
# jedi-0.18.1          | 982 KB    |            |   0%
# jedi-0.18.1          | 982 KB    | 1          |   2%
# jedi-0.18.1          | 982 KB    | ########9  |  90%
# jedi-0.18.1          | 982 KB    | ########## | 100%
#
# pyopenssl-22.0.0     | 50 KB     |            |   0%
# pyopenssl-22.0.0     | 50 KB     | ###2       |  32%
# pyopenssl-22.0.0     | 50 KB     | ########## | 100%
#
# pip-22.2.2           | 2.3 MB    |            |   0%
# pip-22.2.2           | 2.3 MB    |            |   1%
# pip-22.2.2           | 2.3 MB    | ###6       |  36%
# pip-22.2.2           | 2.3 MB    | ########2  |  82%
# pip-22.2.2           | 2.3 MB    | ########## | 100%
#
# jupyterlab-3.4.4     | 3.8 MB    |            |   0%
# jupyterlab-3.4.4     | 3.8 MB    |            |   0%
# jupyterlab-3.4.4     | 3.8 MB    | ##8        |  28%
# jupyterlab-3.4.4     | 3.8 MB    | #####5     |  55%
# jupyterlab-3.4.4     | 3.8 MB    | ########2  |  82%
# jupyterlab-3.4.4     | 3.8 MB    | ########## | 100%
#
# libvorbis-1.3.7      | 202 KB    |            |   0%
# libvorbis-1.3.7      | 202 KB    | 7          |   8%
# libvorbis-1.3.7      | 202 KB    | ########## | 100%
#
# jpeg-9e              | 292 KB    |            |   0%
# jpeg-9e              | 292 KB    | 5          |   5%
# jpeg-9e              | 292 KB    | ########## | 100%
#
# asttokens-2.0.5      | 20 KB     |            |   0%
# asttokens-2.0.5      | 20 KB     | #######8   |  78%
# asttokens-2.0.5      | 20 KB     | ########## | 100%
#
# traitlets-5.1.1      | 84 KB     |            |   0%
# traitlets-5.1.1      | 84 KB     | #8         |  19%
# traitlets-5.1.1      | 84 KB     | ########## | 100%
#
# conda-build-3.22.0   | 541 KB    |            |   0%
# conda-build-3.22.0   | 541 KB    | 2          |   3%
# conda-build-3.22.0   | 541 KB    | ########## | 100%
# conda-build-3.22.0   | 541 KB    | ########## | 100%
#
# conda-repo-cli-1.0.2 | 133 KB    |            |   0%
# conda-repo-cli-1.0.2 | 133 KB    | #2         |  12%
# conda-repo-cli-1.0.2 | 133 KB    | ########## | 100%
# conda-repo-cli-1.0.2 | 133 KB    | ########## | 100%
#
# qtwebkit-5.212       | 10.3 MB   |            |   0%
# qtwebkit-5.212       | 10.3 MB   |            |   0%
# qtwebkit-5.212       | 10.3 MB   | #          |  10%
# qtwebkit-5.212       | 10.3 MB   | ##2        |  23%
# qtwebkit-5.212       | 10.3 MB   | ###2       |  33%
# qtwebkit-5.212       | 10.3 MB   | ####5      |  45%
# qtwebkit-5.212       | 10.3 MB   | #####7     |  57%
# qtwebkit-5.212       | 10.3 MB   | ######9    |  70%
# qtwebkit-5.212       | 10.3 MB   | ########1  |  82%
# qtwebkit-5.212       | 10.3 MB   | #########4 |  94%
# qtwebkit-5.212       | 10.3 MB   | ########## | 100%
#
# urllib3-1.26.12      | 185 KB    |            |   0%
# urllib3-1.26.12      | 185 KB    | 8          |   9%
# urllib3-1.26.12      | 185 KB    | ########## | 100%
# urllib3-1.26.12      | 185 KB    | ########## | 100%
#
# libtiff-4.4.0        | 832 KB    |            |   0%
# libtiff-4.4.0        | 832 KB    | 1          |   2%
# libtiff-4.4.0        | 832 KB    | ########## | 100%
# libtiff-4.4.0        | 832 KB    | ########## | 100%
#
# anyio-3.5.0          | 167 KB    |            |   0%
# anyio-3.5.0          | 167 KB    | 9          |  10%
# anyio-3.5.0          | 167 KB    | ########## | 100%
# anyio-3.5.0          | 167 KB    | ########## | 100%
#
# qtpy-2.2.0           | 106 KB    |            |   0%
# qtpy-2.2.0           | 106 KB    | #5         |  15%
# qtpy-2.2.0           | 106 KB    | ########## | 100%
# qtpy-2.2.0           | 106 KB    | ########## | 100%
#
# pandocfilters-1.5.0  | 11 KB     |            |   0%
# pandocfilters-1.5.0  | 11 KB     | ########## | 100%
# pandocfilters-1.5.0  | 11 KB     | ########## | 100%
#
# py-lief-0.11.5       | 1.7 MB    |            |   0%
# py-lief-0.11.5       | 1.7 MB    |            |   1%
# py-lief-0.11.5       | 1.7 MB    | #######3   |  73%
# py-lief-0.11.5       | 1.7 MB    | ########## | 100%
#
# backports-1.1        | 4 KB      |            |   0%
# backports-1.1        | 4 KB      | ########## | 100%
# backports-1.1        | 4 KB      | ########## | 100%
#
# attrs-21.4.0         | 51 KB     |            |   0%
# attrs-21.4.0         | 51 KB     | ###1       |  32%
# attrs-21.4.0         | 51 KB     | ########## | 100%
#
# m2-msys2-runtime-2.5 | 3.0 MB    |            |   0%
# m2-msys2-runtime-2.5 | 3.0 MB    |            |   1%
# m2-msys2-runtime-2.5 | 3.0 MB    | ####4      |  45%
# m2-msys2-runtime-2.5 | 3.0 MB    | #########9 | 100%
# m2-msys2-runtime-2.5 | 3.0 MB    | ########## | 100%
#
# debugpy-1.5.1        | 2.6 MB    |            |   0%
# debugpy-1.5.1        | 2.6 MB    |            |   1%
# debugpy-1.5.1        | 2.6 MB    | ######4    |  64%
# debugpy-1.5.1        | 2.6 MB    | ########## | 100%
#
# libogg-1.3.5         | 33 KB     |            |   0%
# libogg-1.3.5         | 33 KB     | ####9      |  49%
# libogg-1.3.5         | 33 KB     | ########## | 100%
#
# tornado-6.2          | 609 KB    |            |   0%
# tornado-6.2          | 609 KB    | 2          |   3%
# tornado-6.2          | 609 KB    | ########## | 100%
# tornado-6.2          | 609 KB    | ########## | 100%
#
# click-8.0.4          | 155 KB    |            |   0%
# click-8.0.4          | 155 KB    | #          |  10%
# click-8.0.4          | 155 KB    | ########## | 100%
#
# pycosat-0.6.4        | 74 KB     |            |   0%
# pycosat-0.6.4        | 74 KB     | ##1        |  22%
# pycosat-0.6.4        | 74 KB     | ########## | 100%
#
# beautifulsoup4-4.11. | 190 KB    |            |   0%
# beautifulsoup4-4.11. | 190 KB    | 8          |   8%
# beautifulsoup4-4.11. | 190 KB    | ########## | 100%
# beautifulsoup4-4.11. | 190 KB    | ########## | 100%
#
# libxml2-2.9.14       | 1.5 MB    |            |   0%
# libxml2-2.9.14       | 1.5 MB    | 1          |   1%
# libxml2-2.9.14       | 1.5 MB    | ########## | 100%
# libxml2-2.9.14       | 1.5 MB    | ########## | 100%
#
# notebook-shim-0.2.2  | 23 KB     |            |   0%
# notebook-shim-0.2.2  | 23 KB     | ######9    |  69%
# notebook-shim-0.2.2  | 23 KB     | ########## | 100%
#
# libxslt-1.1.35       | 407 KB    |            |   0%
# libxslt-1.1.35       | 407 KB    | 3          |   4%
# libxslt-1.1.35       | 407 KB    | ########## | 100%
#
# nbconvert-6.4.4      | 517 KB    |            |   0%
# nbconvert-6.4.4      | 517 KB    | 3          |   3%
# nbconvert-6.4.4      | 517 KB    | ########## | 100%
# nbconvert-6.4.4      | 517 KB    | ########## | 100%
#
# filelock-3.6.0       | 12 KB     |            |   0%
# filelock-3.6.0       | 12 KB     | ########## | 100%
# filelock-3.6.0       | 12 KB     | ########## | 100%
#
# requests-2.28.1      | 99 KB     |            |   0%
# requests-2.28.1      | 99 KB     | #6         |  16%
# requests-2.28.1      | 99 KB     | ########## | 100%
#
# tqdm-4.64.1          | 143 KB    |            |   0%
# tqdm-4.64.1          | 143 KB    | #1         |  11%
# tqdm-4.64.1          | 143 KB    | ########## | 100%
# tqdm-4.64.1          | 143 KB    | ########## | 100%
#
# numpy-1.23.3         | 11 KB     |            |   0%
# numpy-1.23.3         | 11 KB     | ########## | 100%
# numpy-1.23.3         | 11 KB     | ########## | 100%
#
# pyparsing-3.0.9      | 152 KB    |            |   0%
# pyparsing-3.0.9      | 152 KB    | #          |  11%
# pyparsing-3.0.9      | 152 KB    | ########## | 100%
#
# soupsieve-2.3.2.post | 66 KB     |            |   0%
# soupsieve-2.3.2.post | 66 KB     | ##4        |  24%
# soupsieve-2.3.2.post | 66 KB     | ########## | 100%
#
# gstreamer-1.18.5     | 1.7 MB    |            |   0%
# gstreamer-1.18.5     | 1.7 MB    |            |   1%
# gstreamer-1.18.5     | 1.7 MB    | #########4 |  95%
# gstreamer-1.18.5     | 1.7 MB    | ########## | 100%
#
# jupyter_core-4.11.2  | 98 KB     |            |   0%
# jupyter_core-4.11.2  | 98 KB     | #6         |  16%
# jupyter_core-4.11.2  | 98 KB     | ########## | 100%
#
# setuptools-65.5.0    | 1.1 MB    |            |   0%
# setuptools-65.5.0    | 1.1 MB    | 1          |   1%
# setuptools-65.5.0    | 1.1 MB    | ########## | 100%
# setuptools-65.5.0    | 1.1 MB    | ########## | 100%
#
# pycparser-2.21       | 94 KB     |            |   0%
# pycparser-2.21       | 94 KB     | #6         |  17%
# pycparser-2.21       | 94 KB     | ########## | 100%
#
# libffi-3.4.2         | 107 KB    |            |   0%
# libffi-3.4.2         | 107 KB    | #4         |  15%
# libffi-3.4.2         | 107 KB    | ########## | 100%
# libffi-3.4.2         | 107 KB    | ########## | 100%
#
# certifi-2022.9.24    | 154 KB    |            |   0%
# certifi-2022.9.24    | 154 KB    | #          |  10%
# certifi-2022.9.24    | 154 KB    | ########## | 100%
#
# liblief-0.11.5       | 2.1 MB    |            |   0%
# liblief-0.11.5       | 2.1 MB    |            |   1%
# liblief-0.11.5       | 2.1 MB    | #######7   |  78%
# liblief-0.11.5       | 2.1 MB    | ########## | 100%
#
# sqlite-3.39.3        | 804 KB    |            |   0%
# sqlite-3.39.3        | 804 KB    | 1          |   2%
# sqlite-3.39.3        | 804 KB    | ########## | 100%
# sqlite-3.39.3        | 804 KB    | ########## | 100%
#
# gst-plugins-base-1.1 | 1.7 MB    |            |   0%
# gst-plugins-base-1.1 | 1.7 MB    |            |   1%
# gst-plugins-base-1.1 | 1.7 MB    | #########9 | 100%
# gst-plugins-base-1.1 | 1.7 MB    | ########## | 100%
#
# scikit-learn-1.1.3   | 6.3 MB    |            |   0%
# scikit-learn-1.1.3   | 6.3 MB    |            |   0%
# scikit-learn-1.1.3   | 6.3 MB    | ##6        |  26%
# scikit-learn-1.1.3   | 6.3 MB    | #####8     |  58%
# scikit-learn-1.1.3   | 6.3 MB    | ########4  |  84%
# scikit-learn-1.1.3   | 6.3 MB    | ########## | 100%
#
# joblib-1.1.1         | 383 KB    |            |   0%
# joblib-1.1.1         | 383 KB    | 4          |   4%
# joblib-1.1.1         | 383 KB    | ########## | 100%
# joblib-1.1.1         | 383 KB    | ########## | 100%
#
# typing_extensions-4. | 42 KB     |            |   0%
# typing_extensions-4. | 42 KB     | ###8       |  38%
# typing_extensions-4. | 42 KB     | ########## | 100%
#
# glib-2.69.1          | 1.6 MB    |            |   0%
# glib-2.69.1          | 1.6 MB    |            |   1%
# glib-2.69.1          | 1.6 MB    | ########## | 100%
# glib-2.69.1          | 1.6 MB    | ########## | 100%
#
# nbclient-0.5.13      | 108 KB    |            |   0%
# nbclient-0.5.13      | 108 KB    | #4         |  15%
# nbclient-0.5.13      | 108 KB    | ########## | 100%
#
# idna-3.4             | 93 KB     |            |   0%
# idna-3.4             | 93 KB     | #7         |  17%
# idna-3.4             | 93 KB     | ########## | 100%
#
# tzdata-2022f         | 115 KB    |            |   0%
# tzdata-2022f         | 115 KB    | #3         |  14%
# tzdata-2022f         | 115 KB    | ########## | 100%
# tzdata-2022f         | 115 KB    | ########## | 100%
#
# zeromq-4.3.4         | 4.2 MB    |            |   0%
# zeromq-4.3.4         | 4.2 MB    |            |   0%
# zeromq-4.3.4         | 4.2 MB    | ####7      |  48%
# zeromq-4.3.4         | 4.2 MB    | ########## | 100%
# zeromq-4.3.4         | 4.2 MB    | ########## | 100%
#
# qt-webengine-5.15.9  | 48.9 MB   |            |   0%
# qt-webengine-5.15.9  | 48.9 MB   |            |   0%
# qt-webengine-5.15.9  | 48.9 MB   | 4          |   5%
# qt-webengine-5.15.9  | 48.9 MB   | #          |  11%
# qt-webengine-5.15.9  | 48.9 MB   | #5         |  15%
# qt-webengine-5.15.9  | 48.9 MB   | #9         |  19%
# qt-webengine-5.15.9  | 48.9 MB   | ##3        |  24%
# qt-webengine-5.15.9  | 48.9 MB   | ##7        |  28%
# qt-webengine-5.15.9  | 48.9 MB   | ###        |  31%
# qt-webengine-5.15.9  | 48.9 MB   | ###4       |  34%
# qt-webengine-5.15.9  | 48.9 MB   | ####       |  41%
# qt-webengine-5.15.9  | 48.9 MB   | ####5      |  45%
# qt-webengine-5.15.9  | 48.9 MB   | ####9      |  49%
# qt-webengine-5.15.9  | 48.9 MB   | #####3     |  53%
# qt-webengine-5.15.9  | 48.9 MB   | #####6     |  57%
# qt-webengine-5.15.9  | 48.9 MB   | #####9     |  60%
# qt-webengine-5.15.9  | 48.9 MB   | ######5    |  65%
# qt-webengine-5.15.9  | 48.9 MB   | #######    |  70%
# qt-webengine-5.15.9  | 48.9 MB   | #######5   |  75%
# qt-webengine-5.15.9  | 48.9 MB   | #######9   |  79%
# qt-webengine-5.15.9  | 48.9 MB   | ########2  |  83%
# qt-webengine-5.15.9  | 48.9 MB   | ########6  |  86%
# qt-webengine-5.15.9  | 48.9 MB   | #########  |  91%
# qt-webengine-5.15.9  | 48.9 MB   | #########6 |  96%
# qt-webengine-5.15.9  | 48.9 MB   | ########## | 100%
#
# pkginfo-1.8.3        | 62 KB     |            |   0%
# pkginfo-1.8.3        | 62 KB     | ##5        |  26%
# pkginfo-1.8.3        | 62 KB     | ########## | 100%
#
# libsodium-1.0.18     | 477 KB    |            |   0%
# libsodium-1.0.18     | 477 KB    | 3          |   3%
# libsodium-1.0.18     | 477 KB    | ########## | 100%
# libsodium-1.0.18     | 477 KB    | ########## | 100%
#
# conda-token-0.4.0    | 13 KB     |            |   0%
# conda-token-0.4.0    | 13 KB     | ########## | 100%
# conda-token-0.4.0    | 13 KB     | ########## | 100%
#
# pywinpty-2.0.2       | 200 KB    |            |   0%
# pywinpty-2.0.2       | 200 KB    | 8          |   8%
# pywinpty-2.0.2       | 200 KB    | ########## | 100%
# pywinpty-2.0.2       | 200 KB    | ########## | 100%
#
# toolz-0.12.0         | 106 KB    |            |   0%
# toolz-0.12.0         | 106 KB    | #5         |  15%
# toolz-0.12.0         | 106 KB    | ########## | 100%
# toolz-0.12.0         | 106 KB    | ########## | 100%
#
# m2-patch-2.7.5       | 89 KB     |            |   0%
# m2-patch-2.7.5       | 89 KB     | #8         |  18%
# m2-patch-2.7.5       | 89 KB     | ########## | 100%
#
# anaconda-client-1.11 | 165 KB    |            |   0%
# anaconda-client-1.11 | 165 KB    | 9          |  10%
# anaconda-client-1.11 | 165 KB    | ########## | 100%
# anaconda-client-1.11 | 165 KB    | ########## | 100%
#
# sip-6.6.2            | 434 KB    |            |   0%
# sip-6.6.2            | 434 KB    | 3          |   4%
# sip-6.6.2            | 434 KB    | ########## | 100%
# sip-6.6.2            | 434 KB    | ########## | 100%
#
# pillow-9.2.0         | 908 KB    |            |   0%
# pillow-9.2.0         | 908 KB    | 1          |   2%
# pillow-9.2.0         | 908 KB    | ########## | 100%
# pillow-9.2.0         | 908 KB    | ########## | 100%
#
# pyjwt-2.4.0          | 38 KB     |            |   0%
# pyjwt-2.4.0          | 38 KB     | ####2      |  42%
# pyjwt-2.4.0          | 38 KB     | ########## | 100%
#
# qt-main-5.15.2       | 50.0 MB   |            |   0%
# qt-main-5.15.2       | 50.0 MB   |            |   0%
# qt-main-5.15.2       | 50.0 MB   | 4          |   5%
# qt-main-5.15.2       | 50.0 MB   | 9          |  10%
# qt-main-5.15.2       | 50.0 MB   | #4         |  14%
# qt-main-5.15.2       | 50.0 MB   | #8         |  19%
# qt-main-5.15.2       | 50.0 MB   | ##2        |  23%
# qt-main-5.15.2       | 50.0 MB   | ##6        |  27%
# qt-main-5.15.2       | 50.0 MB   | ###        |  31%
# qt-main-5.15.2       | 50.0 MB   | ###3       |  34%
# qt-main-5.15.2       | 50.0 MB   | ###9       |  40%
# qt-main-5.15.2       | 50.0 MB   | ####4      |  45%
# qt-main-5.15.2       | 50.0 MB   | ####8      |  49%
# qt-main-5.15.2       | 50.0 MB   | #####3     |  53%
# qt-main-5.15.2       | 50.0 MB   | #####7     |  57%
# qt-main-5.15.2       | 50.0 MB   | ######     |  60%
# qt-main-5.15.2       | 50.0 MB   | ######3    |  64%
# qt-main-5.15.2       | 50.0 MB   | ######8    |  69%
# qt-main-5.15.2       | 50.0 MB   | #######2   |  73%
# qt-main-5.15.2       | 50.0 MB   | #######8   |  79%
# qt-main-5.15.2       | 50.0 MB   | ########3  |  83%
# qt-main-5.15.2       | 50.0 MB   | ########7  |  87%
# qt-main-5.15.2       | 50.0 MB   | #########  |  90%
# qt-main-5.15.2       | 50.0 MB   | #########6 |  96%
# qt-main-5.15.2       | 50.0 MB   | ########## | 100%
#
# python-fastjsonschem | 231 KB    |            |   0%
# python-fastjsonschem | 231 KB    | 6          |   7%
# python-fastjsonschem | 231 KB    | ########## | 100%
# python-fastjsonschem | 231 KB    | ########## | 100%
#
# websocket-client-0.5 | 69 KB     |            |   0%
# websocket-client-0.5 | 69 KB     | ##3        |  23%
# websocket-client-0.5 | 69 KB     | ########## | 100%
#
# markupsafe-2.0.1     | 24 KB     |            |   0%
# markupsafe-2.0.1     | 24 KB     | ######7    |  67%
# markupsafe-2.0.1     | 24 KB     | ########## | 100%
#
# ujson-5.4.0          | 44 KB     |            |   0%
# ujson-5.4.0          | 44 KB     | ###6       |  37%
# ujson-5.4.0          | 44 KB     | ########## | 100%
#
# tbb-2021.6.0         | 135 KB    |            |   0%
# tbb-2021.6.0         | 135 KB    | #1         |  12%
# tbb-2021.6.0         | 135 KB    | ########## | 100%
#
# conda-content-trust- | 86 KB     |            |   0%
# conda-content-trust- | 86 KB     | #8         |  19%
# conda-content-trust- | 86 KB     | ########## | 100%
#
# scipy-1.9.3          | 18.0 MB   |            |   0%
# scipy-1.9.3          | 18.0 MB   |            |   0%
# scipy-1.9.3          | 18.0 MB   | #6         |  16%
# scipy-1.9.3          | 18.0 MB   | ###        |  31%
# scipy-1.9.3          | 18.0 MB   | ####2      |  43%
# scipy-1.9.3          | 18.0 MB   | #####3     |  54%
# scipy-1.9.3          | 18.0 MB   | ######1    |  62%
# scipy-1.9.3          | 18.0 MB   | ######8    |  69%
# scipy-1.9.3          | 18.0 MB   | ########2  |  83%
# scipy-1.9.3          | 18.0 MB   | ########## | 100%
# scipy-1.9.3          | 18.0 MB   | ########## | 100%
#
# wheel-0.37.1         | 33 KB     |            |   0%
# wheel-0.37.1         | 33 KB     | ####9      |  49%
# wheel-0.37.1         | 33 KB     | ########## | 100%
#
# entrypoints-0.4      | 17 KB     |            |   0%
# entrypoints-0.4      | 17 KB     | #########5 |  96%
# entrypoints-0.4      | 17 KB     | ########## | 100%
#
# matplotlib-inline-0. | 17 KB     |            |   0%
# matplotlib-inline-0. | 17 KB     | #########3 |  93%
# matplotlib-inline-0. | 17 KB     | ########## | 100%
#
# packaging-21.3       | 36 KB     |            |   0%
# packaging-21.3       | 36 KB     | ####3      |  44%
# packaging-21.3       | 36 KB     | ########## | 100%
#
# pyqt5-sip-12.11.0    | 75 KB     |            |   0%
# pyqt5-sip-12.11.0    | 75 KB     | ##1        |  21%
# pyqt5-sip-12.11.0    | 75 KB     | ########## | 100%
#
# ipykernel-6.15.2     | 191 KB    |            |   0%
# ipykernel-6.15.2     | 191 KB    | 8          |   8%
# ipykernel-6.15.2     | 191 KB    | ########## | 100%
# ipykernel-6.15.2     | 191 KB    | ########## | 100%
#
# psutil-5.9.0         | 349 KB    |            |   0%
# psutil-5.9.0         | 349 KB    | 4          |   5%
# psutil-5.9.0         | 349 KB    | ########## | 100%
# psutil-5.9.0         | 349 KB    | ########## | 100%
#
# nest-asyncio-1.5.5   | 16 KB     |            |   0%
# nest-asyncio-1.5.5   | 16 KB     | #########8 |  98%
# nest-asyncio-1.5.5   | 16 KB     | ########## | 100%
#
# terminado-0.13.1     | 31 KB     |            |   0%
# terminado-0.13.1     | 31 KB     | #####1     |  52%
# terminado-0.13.1     | 31 KB     | ########## | 100%
#
# bleach-4.1.0         | 123 KB    |            |   0%
# bleach-4.1.0         | 123 KB    | #3         |  13%
# bleach-4.1.0         | 123 KB    | ########## | 100%
#
# libclang-12.0.0      | 17.8 MB   |            |   0%
# libclang-12.0.0      | 17.8 MB   |            |   0%
# libclang-12.0.0      | 17.8 MB   | #5         |  16%
# libclang-12.0.0      | 17.8 MB   | ###1       |  32%
# libclang-12.0.0      | 17.8 MB   | ####3      |  44%
# libclang-12.0.0      | 17.8 MB   | #####5     |  55%
# libclang-12.0.0      | 17.8 MB   | ######3    |  64%
# libclang-12.0.0      | 17.8 MB   | #######1   |  71%
# libclang-12.0.0      | 17.8 MB   | ########5  |  86%
# libclang-12.0.0      | 17.8 MB   | #########6 |  96%
# libclang-12.0.0      | 17.8 MB   | ########## | 100%
#
# pygments-2.11.2      | 759 KB    |            |   0%
# pygments-2.11.2      | 759 KB    | 2          |   2%
# pygments-2.11.2      | 759 KB    | ########## | 100%
# pygments-2.11.2      | 759 KB    | ########## | 100%
#
# decorator-5.1.1      | 12 KB     |            |   0%
# decorator-5.1.1      | 12 KB     | ########## | 100%
# decorator-5.1.1      | 12 KB     | ########## | 100%
#
# executing-0.8.3      | 18 KB     |            |   0%
# executing-0.8.3      | 18 KB     | ########7  |  88%
# executing-0.8.3      | 18 KB     | ########## | 100%
#
# freetype-2.12.1      | 490 KB    |            |   0%
# freetype-2.12.1      | 490 KB    | 3          |   3%
# freetype-2.12.1      | 490 KB    | ########## | 100%
# freetype-2.12.1      | 490 KB    | ########## | 100%
#
# six-1.16.0           | 18 KB     |            |   0%
# six-1.16.0           | 18 KB     | ########6  |  87%
# six-1.16.0           | 18 KB     | ########## | 100%
#
# zstd-1.5.2           | 509 KB    |            |   0%
# zstd-1.5.2           | 509 KB    | 3          |   3%
# zstd-1.5.2           | 509 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Windows 64-bit packages of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
# done

# %%
conda install imread
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
#
# Note: you may need to restart the kernel to use updated packages.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - imread
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/win-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/win-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#   - https://repo.anaconda.com/pkgs/msys2/win-64
#   - https://repo.anaconda.com/pkgs/msys2/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
import numpy as np
import os
#from scipy.misc import imread, imresize
#import imread, imresize
from skimage.io import imread
from skimage.transform import resize as imresize
import datetime
import os

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.random.set_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('Project_data/val.csv').readlines())
batch_size = 10 #experiment with the batch size

# %%
#math.floor(len(train_doc) / batch_size)
#round(((len(train_doc) / batch_size)-num_batches*batch_size)
#len(train_doc)
len(train_doc) % batch_size
# Out:
# 3

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
import math
# folder_list = train_doc/val_doc
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = 10 #create a list of image numbers you want to use for a particular video
    while True:
        t = np.random.permutation(folder_list)
        num_batches = math.floor(len(folder_list) / batch_size) # calculate the number of batches (number of videos / batch size)
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    batch_data[folder,idx,:,:,0] = #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = #normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches
# Out:
#   Cell In [7], line 3
#     img_idx = #create a list of image numbers you want to use for a particular video
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = 'Project_data/train'
val_path = 'Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 4# choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 4

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

#write your model here

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
